# %%
import s3fs
import xarray as xr
import zarr
import dask.array as da

# %%
array = xr.DataArray(da.zeros((1000,1000,3)))

# %%
import zarr
import s3fs
# AWS S3 path
s3_path = 'zarrexample' 
# Initilize the S3 file system
s3 = s3fs.S3FileSystem(client_kwargs={"endpoint_url":'http://minio:9000' })
store = s3fs.S3Map(root=s3_path, s3=s3, check=False)
it = array.to_dataset(name="peter").to_zarr(store=store)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-2e0f80edb827> in <module>
#       6 s3 = s3fs.S3FileSystem(client_kwargs={"endpoint_url":'http://minio:9000' })
#       7 store = s3fs.S3Map(root=s3_path, s3=s3, check=False)
# ----> 8 it = array.to_dataset(name="peter").to_zarr(store=store)
#
# /opt/conda/lib/python3.7/site-packages/xarray/core/dataset.py in to_zarr(self, store, mode, synchronizer, group, encoding, compute, consolidated, append_dim)
#    1625             compute=compute,
#    1626             consolidated=consolidated,
# -> 1627             append_dim=append_dim,
#    1628         )
#    1629
#
# /opt/conda/lib/python3.7/site-packages/xarray/backends/api.py in to_zarr(dataset, store, mode, synchronizer, group, encoding, compute, consolidated, append_dim)
#    1320         synchronizer=synchronizer,
#    1321         group=group,
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ParamValidationError                      Traceback (most recent call last)
# <ipython-input-17-0d0c15ba306d> in <module>
# ----> 1 array.to_dataset(name="peter").to_zarr(store=store)
#
# /opt/conda/lib/python3.7/site-packages/xarray/core/dataset.py in to_zarr(self, store, mode, synchronizer, group, encoding, compute, consolidated, append_dim)
#    1625             compute=compute,
#    1626             consolidated=consolidated,
# -> 1627             append_dim=append_dim,
#    1628         )
#    1629
#
# /opt/conda/lib/python3.7/site-packages/xarray/backends/api.py in to_zarr(dataset, store, mode, synchronizer, group, encoding, compute, consolidated, append_dim)
#    1320         synchronizer=synchronizer,
#    1321         group=group,
# -> 1322         consolidate_on_close=consolidated,
#    1323     )
#    1324     zstore.append_dim = append_dim
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e3af494f6bb8> in <module>
# ----> 1 ds = xr.open_zarr(store=store, consolidated=True)
#
# NameError: name 'xr' is not defined
