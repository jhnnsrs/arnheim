# %%
import matplotlib.pyplot as plt
import numpy as np
import dask.array as da
import zarr as zr
import django
from dask.distributed import Client, progress

django.setup()
from elements.models import Zarr
from dask.distributed import Client, progress
c = Client()
import xarray, h5py
# Out:
# Debugging build
# Hallo

# %%
from metamorphers.models import Metamorphing

# %%
met = Metamorphing.objects.last()

# %%
array = met.representation.loadArray()

print(array.dtype)
array = array[:, :, :, :, 0]
# Out:
# /code/media/zarr/sample-240
# float16

# %%
it = array.sel(channels="Ch1-T2").astype('uint16')

# %%
it.dtype
# Out:
# dtype('uint16')

# %%
from cloudvolume import CloudVolume

# %%
info = CloudVolume.create_new_info(
	num_channels = 1,
	layer_type = 'image', # 'image' or 'segmentation'
	data_type = 'uint16', # can pick any popular uint
	encoding = 'raw', # other options: 'jpeg', 'compressed_segmentation' (req. uint32 or uint64)
	resolution = [ 4, 4, 4 ], # X,Y,Z values in nanometers
	voxel_offset = [ 0, 0, 1 ], # values X,Y,Z values in voxels
	chunk_size = [ 1024, 1024, 1 ], # rechunk of image X,Y,Z in voxels
	volume_size = it.shape, # X,Y,Z size in voxels
)

# %%
vol = CloudVolume('file:///cloud/test', info=info)
vol.provenance.description = "Test"
vol.provenance.owners = ['email_address_for_uploader/imager'] # list of contact email addresses

# %%
vol.commit_info() # generates gs://bucket/dataset/layer/info json file
vol.commit_provenance() # generates gs://bucket/dataset/layer/provenance json file

# %%
vol[:,:,:] = it.values
# Out:
# Uploading:   0%|          | 0/112 [00:00<?, ?it/s]
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00, 12.76it/s]
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  5.90it/s]
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  5.49it/s]
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  4.87it/s]
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  5.15it/s]
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  5.67it/s]
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  5.46it/s]
#
#
#
# Uploading:  20%|█▉        | 22/112 [00:00<00:00, 109.51it/s][A
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  4.26it/s]
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  4.48it/s]
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  3.88it/s]
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  3.26it/s]
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  4.04it/s]
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  4.75it/s]
#
#
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  5.94it/s]
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  2.60it/s]
#
#
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  7.05it/s]
#
#
#
#
#
#
#
#
#
# Uploading:  29%|██▉       | 33/112 [00:00<00:00, 82.57it/s] [A
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  2.30it/s]
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  3.87it/s]
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  3.80it/s]
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  7.84it/s]
# Uploading:  37%|███▋      | 41/112 [00:00<00:01, 49.15it/s]
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  6.39it/s]
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  3.31it/s]
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  1.85it/s]
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  2.31it/s]
#
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  5.70it/s]
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  1.54it/s]
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  4.08it/s]
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  1.13it/s]
#
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  4.21it/s]
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  9.78it/s]
#
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  4.79it/s]
#
#
#
#
#
#
#
#
#
#
# Uploading:  40%|████      | 45/112 [00:01<00:01, 36.97it/s]A
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  1.61it/s]
#
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  4.78it/s]
#
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  2.34it/s]
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  6.03it/s]
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  3.82it/s]
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  1.75it/s]
#
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  2.68it/s]
#
#
#
#
#
#
# Uploading:  51%|█████     | 57/112 [00:01<00:01, 37.00it/s]
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  3.54it/s]
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  4.19it/s]
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  3.63it/s]
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  2.36it/s]
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  1.59it/s]
#
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  2.98it/s]
#
#
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  3.27it/s]
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  9.89it/s]
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  4.63it/s]
#
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  3.44it/s]
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  4.31it/s]
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
# Uploading:  58%|█████▊    | 65/112 [00:01<00:01, 38.69it/s]
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  1.69it/s]
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  8.73it/s]
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  3.28it/s]
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  5.10it/s]
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00, 10.18it/s]
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  5.49it/s]
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00, 11.10it/s]
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  2.45it/s]
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  5.21it/s]
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  3.67it/s]
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  2.42it/s]
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  8.74it/s]
# Uploading:  70%|██████▉   | 78/112 [00:01<00:00, 39.79it/s]
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00, 12.35it/s]
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  2.65it/s]
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  3.46it/s]
#
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  3.36it/s]
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  3.63it/s]
#
#
#
#
#
# Uploading:  79%|███████▉  | 89/112 [00:02<00:00, 39.15it/s]
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  6.52it/s]
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  5.53it/s]
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  3.80it/s]
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  5.04it/s]
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  4.96it/s]
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  2.92it/s]
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  3.64it/s]
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  5.63it/s]
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  3.84it/s]
#
#
#
#
#
#
#
# Uploading:  87%|████████▋ | 97/112 [00:02<00:00, 42.43it/s]
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  9.46it/s]
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  4.59it/s]
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  2.78it/s]
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  5.01it/s]
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  2.84it/s]
#
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  3.26it/s]
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  6.85it/s]
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# Uploading:  94%|█████████▍| 105/112 [00:02<00:00, 42.20it/s]
#
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  4.12it/s]
#
#
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  3.19it/s]
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  2.98it/s]
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  3.76it/s]
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  3.04it/s]
#
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  6.99it/s]
#
#
#
#
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  5.71it/s]
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  3.89it/s]
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  3.13it/s]
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  2.96it/s]
#
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  3.23it/s]
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  6.96it/s]
#
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  7.46it/s]
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  6.80it/s]
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  4.34it/s]
#
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  7.09it/s]
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  8.10it/s]
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
# Uploading:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  3.74it/s]
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  4.99it/s]
#
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  5.90it/s]
# Uploading: 100%|██████████| 1/1 [00:00<00:00, 19.91it/s]
#
#
#
#
# Uploading: 100%|██████████| 1/1 [00:00<00:00,  6.07it/s]
#
# Uploading: 210it [00:02, 55.67it/s]                         [A

# %%
import napari

with napari.gui_qt():
    # specify contrast_limits and is_pyramid=False with big data
    # to avoid unecessary computations
    napari.view_image(it, contrast_limits=[0,2000], is_pyramid=False)
# Out:
# WARNING: Could not load the Qt platform plugin "xcb" in "" even though it was found.

# %%
# %gui qt
# Out:
# tornado.application - ERROR - Exception in callback functools.partial(<function Kernel.enter_eventloop.<locals>.advance_eventloop at 0x7f26e4fa1950>)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/opt/conda/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 314, in advance_eventloop
#     eventloop(self)
#   File "/opt/conda/lib/python3.7/site-packages/ipykernel/eventloops.py", line 129, in loop_qt5
#     return loop_qt4(kernel)
#   File "/opt/conda/lib/python3.7/site-packages/ipykernel/eventloops.py", line 116, in loop_qt4
#     kernel.app = get_app_qt4([" "])
#   File "/opt/conda/lib/python3.7/site-packages/IPython/lib/guisupport.py", line 114, in get_app_qt4
#     from IPython.external.qt_for_kernel import QtGui
#   File "/opt/conda/lib/python3.7/site-packages/IPython/external/qt_for_kernel.py", line 95, in <module>
#     QtCore, QtGui, QtSvg, QT_API = load_qt(api_opts)
#   File "/opt/conda/lib/python3.7/site-packages/IPython/external/qt_loaders.py", line 329, in load_qt
#     api_options))
# ImportError:
#     Could not load requested Qt binding. Please ensure that
#     PyQt4 >= 4.7, PyQt5, PySide >= 1.0.3 or PySide2 is available,
#     and only one is imported per session.
#
#     Currently-imported Qt library:                              None
#     PyQt4 available (requires QtCore, QtGui, QtSvg):            False
#     PyQt5 available (requires QtCore, QtGui, QtSvg, QtWidgets): False
#     PySide >= 1.0.3 installed:                                  False
#     PySide2 installed:                                          True
#     Tried to load:                                              ['pyqt5']

# %%
import napari

with napari.gui_qt():
    # specify contrast_limits and is_pyramid=False with big data
    # to avoid unecessary computations
    napari.view_image(it, contrast_limits=[0,2000], is_pyramid=False)
# Out:
# /opt/conda/lib/python3.7/site-packages/qtpy/__init__.py:216: RuntimeWarning: Selected binding "pyqt5" could not be found, using "pyside2"
#   'using "{}"'.format(initial_api, API), RuntimeWarning)
# WARNING: Could not load the Qt platform plugin "xcb" in "" even though it was found.

# %%
cmax = array.max()
cmin = array.min()
high = 255
low = 0

# %%
cscale = cmax - cmin
scale = float(high - low) / cscale

# %%
scaled = (array - cmin) * scale + low
final = (scaled.clip(low, high) + 0.5)

# %%
emptychannel = xarray.DataArray((da.zeros((1256,1256,1,28))), dims=array.dims, coords={"channels":["empty",]})
end = xarray.concat([array,emptychannel],dim="channels")
end.attrs = array.attrs

# %%
shape_3d = end.shape[0:3]

# %%
rgb_dtype = np.dtype([('R', 'u1'), ('G', 'u1'), ('B', 'u1')])

# %%
contugious = np.ascontiguousarray(end, dtype='u1')
