# %%
import matplotlib.pyplot as plt
import numpy as np
import dask.array as da
import zarr as zr
import xarray as xr
import django
from dask.distributed import Client, progress

import dask_image.ndfilters

django.setup()
from bioconverter.models import Representation

# %%
da.interp()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-be295b2e4cf5> in <module>
# ----> 1 da.interp()
#
# AttributeError: module 'dask.array' has no attribute 'interp'

# %%
prewitt = Representation.objects.last()

# %%
prewitt
# Out:
# <Representation: Prewitt of Initial Stack>

# %%
array = prewitt.array
array
# Out:
# <xarray.DataArray 'data' (x: 1256, y: 1256, c: 2, z: 28, t: 1)>
# dask.array<zarr, shape=(1256, 1256, 2, 28, 1), dtype=float64, chunksize=(157, 314, 1, 7, 1), chunktype=numpy.ndarray>
# Coordinates:
#   * c         (c) int64 0 1
#     channels  (c) [('Index', '<i8'), ('Name', '<U250'), ('EmissionWavelength', '<f8'), ('ExcitationWavelength', '<f8'), ('IlluminationType', '<U250'), ('AcquisitionMode', '<U250'), ('Color', '<U250'), ('SamplesPerPixel', '<i8')] dask.array<chunksize=(2,), meta=np.ndarray>
#     phsyz     (z) float64 dask.array<chunksize=(28,), meta=np.ndarray>
#     physt     (t) float64 dask.array<chunksize=(1,), meta=np.ndarray>
#     physx     (x) float64 dask.array<chunksize=(1256,), meta=np.ndarray>
#     physy     (y) float64 dask.array<chunksize=(1256,), meta=np.ndarray>
# ...

# %%
it = array.sel(t=0).max(dim="z").sel(c=1)

# %%
it.plot.imshow()

# %%
full = it.data

# %%
zero = da.zeros((it.x.size, it.y.size, 1))

# %%
together = da.concatenate([full, zero], axis=2)

# %%
nana = xr.DataArray(together)

# %%
nana.plot.imshow(rgb="dim_2")

# %%
it = array
prewittfiltered = dask_image.ndfilters.prewitt(it.data)

# %%
def prepend(el, string= "Prewitt of"):
    items = el.channels.data.compute()
    for merge in items:
        merge["Name"] = f"{string} {merge['Name']}"
    return items

# %%
c = prepend(it, string="Prewitt of")

# %%
channels = xr.DataArray(da.array(c), dims="c")

# %%
x = xr.DataArray(prewittfiltered, dims=it.dims, coords={ **it.coords, "channels": channels})

# %%
x.biometa.channels
# Out:
#    Index                 Name  EmissionWavelength  ExcitationWavelength  \
# 0      0  Prewitt of (Ch1-T1)               518.0                 488.0
# 1      1  Prewitt of (Ch1-T2)               585.0                 555.0
#
#   IlluminationType                  AcquisitionMode      Color  \
# 0  Epifluorescence  LaserScanningConfocalMicroscopy   16711935
# 1  Epifluorescence  LaserScanningConfocalMicroscopy  -16776961
#
#    SamplesPerPixel
# 0                1
# 1                1

# %%
array = xr.DataArray(prewittfiltered, dims=["x","y"])
array = array.expand_dims("c")
array = array.transpose("x","y","c")

print(array)
end = xr.DataArray(array, dims=it.dims + ("c",), coords={**it.coords, "channels": channels, "c": [0]})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-1942a78d2665> in <module>
# ----> 1 array = xr.DataArray(prewittfiltered, dims=["x","y"])
#       2 array = array.expand_dims("c")
#       3 array = array.transpose("x","y","c")
#       4
#       5 print(array)
#
# /opt/conda/lib/python3.7/site-packages/xarray/core/dataarray.py in __init__(self, data, coords, dims, name, attrs, encoding, indexes, fastpath)
#     366             data = _check_data_shape(data, coords, dims)
#     367             data = as_compatible_data(data)
# --> 368             coords, dims = _infer_coords_and_dims(data.shape, coords, dims)
#     369             variable = Variable(dims, data, attrs, encoding, fastpath=True)
#     370
#
# /opt/conda/lib/python3.7/site-packages/xarray/core/dataarray.py in _infer_coords_and_dims(shape, coords, dims)
#     118         raise ValueError(
# ...
